# %%
import numpy as np

# %%
def convert_to(a: np.ndarray):
    return np.where(a <= 0, -1, 1)

def convert_back(a: np.ndarray):
    return np.where(a > 0, 1, 0)

# %%
def get_binary(width):
    values = []
    for i in range(2**width):
        str_repr = list(np.binary_repr(i, width))
        str_repr = ','.join(str_repr)
        values.append(np.fromstring(str_repr, dtype=int, sep=','))
    return values

# %%
# input -> output
training_set_multiple = [
    (np.array([1, 1, 1]), np.array([0,0])),
    (np.array([0,0,1]), np.array([1,0]))
]

# already converted
model = np.array([[-1, 1], [1, -1], [-1, 1]])

# %%
inputs = convert_to(np.array([1, 0, 1]))

# %%
result = np.matmul(inputs, model)
convert_back(result)
# Out:
# array([0, 1])

# %%
test_set = get_binary(3)
test_set = [convert_to(test_input) for test_input in test_set]
test_set
# Out:
# [array([-1, -1, -1]),
#  array([-1, -1,  1]),
#  array([-1,  1, -1]),
#  array([-1,  1,  1]),
#  array([ 1, -1, -1]),
#  array([ 1, -1,  1]),
#  array([ 1,  1, -1]),
#  array([1, 1, 1])]

# %%
# results = []
for test_input in test_set:
    result = np.matmul(test_input, model)
    print(f"\nTI: {convert_back(test_input)}, \nMO: {convert_back(result)}")
# Out:
# TI: [0 0 0],
# MO: [1 0]
#
# TI: [0 0 1],
# MO: [0 1]
#
# TI: [0 1 0],
# MO: [1 0]
#
# TI: [0 1 1],
# MO: [1 0]
#
# TI: [1 0 0],
# MO: [0 1]
#
# TI: [1 0 1],
# MO: [0 1]
#
# TI: [1 1 0],
# MO: [1 0]
#
# TI: [1 1 1],
# MO: [0 1]

# %%
def train(training_set: list[tuple[np.ndarray, np.ndarray]]):
    sets = training_set[0]
    inputs, outputs = sets
    model = np.zeros([inputs.size, outputs.size])
    for input, output in training_set:
        # convert inputs / outputs to -1 / 1 form
        input_conv = convert_to(input)
        output_conv = convert_to(output)

        delta_w = np.matmul(input_conv.transpose(), output_conv)
        model = np.add(model,delta_w)

    return model

# %%
inputs, outputs = training_set_multiple[0]
inputs.shape
outputs.transpose().shape
# Out:
# (2,)

# %%
model = train(training_set_multiple)

results = []
for test_input in test_set:
    result = np.matmul(test_input, model)
    print(f"\nTI: {convert_back(test_input)}, \nMO: {convert_back(result)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 inputs, outputs = training_set_multiple
# ----> 2 model = train(training_set_multiple)
#       4 results = []
#       5 for test_input in test_set:
#
# Cell In[51], line 10, in train(training_set)
#       7     input_conv = convert_to(input)
#       8     output_conv = convert_to(output)
# ---> 10     delta_w = np.matmul(input_conv.transpose(), output_conv)
#      11     model = np.add(model,delta_w)
#      13 return model
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 3)
